# %% [markdown]
# <a href="https://colab.research.google.com/github/giampierus/asdetect-be/blob/main/Backend_API_Mistral.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INSTALL API

# %%
# !pip install fastapi uvicorn pyngrok torch
# !pip install pymongo
# !pip install transformers accelerate bitsandbytes torch huggingface_hub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 72.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 77.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 36.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # SETUP MODEL

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from google.colab import userdata
from huggingface_hub import login
import torch

login(userdata.get('HF_TOKEN'))

MODEL_NAME = "mistralai/Mixtral-8x7B-Instruct-v0.1"

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    device_map="auto",
    load_in_4bit=True,
    llm_int8_enable_fp32_cpu_offload=True
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.10k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/720 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json:   0%|          | 0.00/92.7k [00:00<?, ?B/s]
# Fetching 19 files:   0%|          | 0/19 [00:00<?, ?it/s]
# model-00006-of-00019.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00003-of-00019.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00005-of-00019.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00001-of-00019.safetensors:   0%|          | 0.00/4.89G [00:00<?, ?B/s]
# ...

# %% [markdown]
# # TEMPLATE

# %%
trascrizione =
  "transcription": [
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 0.9590937500000001,
      "end": 2.0897187500000003,
      "text": " Com'è ti chiami?"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 2.27534375,
      "end": 3.22034375,
      "text": " Alessandro."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 3.5578437500000004,
      "end": 4.620968749999999,
      "text": " quando sei nato"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 4.806593750000001,
      "end": 6.544718750000001,
      "text": " 11.03.60"
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 8.063468750000002,
      "end": 12.83909375,
      "text": " Ci racconti la tua giornata di ieri da quando ti sei svegliato a quando ti sei messo a letto?"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 13.73346875,
      "end": 53.102843750000005,
      "text": " Ieri esattamente che ho fatto, sono stato, sono uscito perché la temperatura faceva brutto tempo e a casa mi sentivo un po' angosciato. E sono andato da Tony Strino a prendere una fotografia di mia madre, poi sono andato ad accompagnare mia sorella dal medico di famiglia, però aveva preso un appuntamento sbagliato, ma non mia sorella, il medico di famiglia si era sbagliato e doveva andare l'altro venerdì. Sono andato naturalmente a piedi, poi ho comprato delle rosette da una panetteria che sta sopra la me dopo aver camminato a piedi avanti e indietro."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 53.541593750000004,
      "end": 60.696593750000005,
      "text": " E poi siamo tornati a casa. Ieri è venuta la signora delle pulizie nel pomeriggio dopo aver mangiato, dopo che avevo mangiato."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 61.236593750000004,
      "end": 76.00221875000001,
      "text": " ha fatto le pulizie dalle 2 alle 6, però io poi mi sono andato a dormire verso le 7. Mi sono addormentato, mi sono svegliato verso mezzanotte, mi credevo che non mi sveglia e mi addormentavo più, ma mi sono addormentato un'altra volta."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 76.74471875,
      "end": 83.03909375,
      "text": " Mi sono svegliato presto, verso le 4, le 4 e mezza e ora mi sento un po' sangue."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 83.51159375,
      "end": 87.54471875,
      "text": " Ok, va bene, ho capito. Ma lei sente le voci?"
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 87.83159375000001,
      "end": 88.99596875,
      "text": " Adesso..."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 88.99596875,
      "end": 92.32034375,
      "text": " No, qualche posta ma una minima cosa, quasi niente."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 92.67471875000001,
      "end": 96.80909375,
      "text": " Ok, ma mi puoi dire che cosa dicono?"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 98.56409375000001,
      "end": 101.29784375000001,
      "text": " No, non sono voci, sono soprattutto..."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 102.61409375000001,
      "end": 104.21721875,
      "text": " Quello che mi viene..."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 104.97659375,
      "end": 113.27909375,
      "text": " Mi sembra di parlare con mia madre, però non sono voci, sono cose che vengono dall'interno."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 114.86534375000001,
      "end": 121.80096875000001,
      "text": " cioè se faccio bene delle cose, se non le faccio bene, è dovuto a questo fatto della scomparsa di mia madre."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 118.99971875000001,
      "end": 119.53971875,
      "text": "ato"
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 122.02034375000001,
      "end": 123.43784375000001,
      "text": " Non capito, a mia specie è molto."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 124.46721875,
      "end": 126.30659375,
      "text": " Allora"
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 125.42909375,
      "end": 126.35721875,
      "text": " Allora"
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 126.64409375000001,
      "end": 130.89659375000002,
      "text": " Adesso le chiederei qualche altra domanda."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 130.93034375000002,
      "end": 130.94721875000002,
      "text": " Grazie."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 131.36909375000002,
      "end": 134.42346875,
      "text": " Per esempio, mi puoi spiegare il significato di questi proverbi?"
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 135.11534375000002,
      "end": 137.37659375,
      "text": " Chi va con lo zoppo impara a zoppicare."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 138.49034375000002,
      "end": 142.03409375,
      "text": " che praticamente si freguenta una persona che..."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 142.55721875,
      "end": 146.77596875,
      "text": " non sta sulla via giusta, pure lui non sta sulla via giusta."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 147.88971875000001,
      "end": 150.55596875,
      "text": " L'altro è chi ha tempo non aspetti tempo."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 151.36596875,
      "end": 159.90471875,
      "text": " Certo, bisogna sempre, dato che il tempo della vita è limitato, bisogna sempre utilizzarlo nella migliore maniera possibile."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 160.61346875,
      "end": 161.05221875,
      "text": " Attra"
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 161.84534375,
      "end": 163.90409375000002,
      "text": " Che cosa pensa lei dell'amore?"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 166.06409375,
      "end": 178.90596875,
      "text": " che è una cosa bellissima, a secondo di quello che si ha verso il prossimo, verso una donna, verso i propri genitori, verso i fratelli, verso i cognati."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 180.74534375000002,
      "end": 181.36971875,
      "text": " ok"
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 181.75784375,
      "end": 190.14471875,
      "text": " Adesso le faccio qualche domanda su alcune cose che lei mi dice se le capitano, se non le capitano e ogni quanto le danno fastidio."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 190.71846875,
      "end": 195.15659375,
      "text": " Le è mai capitato di pensare che non le viene in mente niente di nuovo?"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 196.60784375,
      "end": 202.32846875,
      "text": " No, qualche volta mi sono bloccato, ma capita soprattutto quando uno si nervosisce."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 203.27346875,
      "end": 203.49284375000002,
      "text": " Grazie."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 203.49284375000002,
      "end": 203.50971875000002,
      "text": " Grazie."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 205.21409375000002,
      "end": 209.04471875000002,
      "text": " Oppure quando ti fanno una cosa che non gradisce all'improvviso."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 209.98971875,
      "end": 213.80346875,
      "text": " Quindi non le è capitato però che non le venga in mente niente di nuovo?"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 214.00596875000002,
      "end": 217.34721875000002,
      "text": " No, di solito non mi viene, quando sto tranquillo non mi viene."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 218.78159375,
      "end": 223.81034375000002,
      "text": " Le è mai capitato di sentire che i pensieri invece svanissero, che perdesse il filo?"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 224.78909375,
      "end": 225.54846875,
      "text": " no"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 226.07159375,
      "end": 237.51284375,
      "text": " Qualche volta, qualche benzo, contemporaneamente più cose mi dimentico, quello che dico, però poi lavorandoci, toccando, cercando di fare cose mie allaterali me le ricordo."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 237.71534375000002,
      "end": 237.83346875,
      "text": " Grazie."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 238.93034375000002,
      "end": 244.06034375000002,
      "text": " E le è mai capitato invece di percepire il pensiero come inibito, rallentato?"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 244.83659375000002,
      "end": 245.22471875000002,
      "text": " no"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 245.71409375000002,
      "end": 245.96721875000003,
      "text": " Grazie."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 246.01784375000003,
      "end": 246.06846875000002,
      "text": " Grazie."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 246.06846875000002,
      "end": 246.40596875000003,
      "text": " Grazie."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 247.26659375000003,
      "end": 254.42159375000003,
      "text": " A volte si sente spinto a pensare a un argomento in particolare, anche se magari vorrebbe pensare ad altro."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 254.82659375000003,
      "end": 258.99471875,
      "text": " Ah, sì, quando è una cosa che mi tocca, questo capita, sì."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 259.16346875,
      "end": 259.45034375,
      "text": " Grazie!"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 260.63159375000004,
      "end": 260.69909375000003,
      "text": " Grazie."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 260.69909375000003,
      "end": 260.73284375000003,
      "text": " Grazie."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 260.73284375000003,
      "end": 260.74971875,
      "text": " Grazie a tutti."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 260.74971875,
      "end": 260.96909375,
      "text": " Grazie."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 260.96909375,
      "end": 261.01971875000004,
      "text": " Grazie."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 262.75784375,
      "end": 270.57096875,
      "text": " è in grado ancora secondo lei di seguire i film e le conversazioni come lo era in passato?"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 271.19534375,
      "end": 275.14409375,
      "text": " No, sono in grado, solo che sono sordo, cioè gli apparecchi non me li metto."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 276.49409375,
      "end": 279.36284375,
      "text": " Vabbè, la non è così, ci sente abbastanza bene."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 280.17284375,
      "end": 286.63596875,
      "text": " Devo alzare il volume del televisore per sentire, comunque non nel caso mio, un sacco di colleghi, cose, c'hanno sopra il problema."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 287.26034375,
      "end": 299.08971875000003,
      "text": " Però non le capita di sentire che non riesce a seguire, eccetera. E invece ha la sensazione che i discorsi propri non siano fluidi, non siano precisi come in passato."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 302.38034375,
      "end": 303.19034375,
      "text": " no"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 304.01721875000004,
      "end": 306.76784375,
      "text": " quando sono stango sucede questo"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 306.91971875,
      "end": 311.67846875000004,
      "text": " Per esempio, io non sto prendendo una macchina. Quando è stato..."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 312.15096875,
      "end": 318.17534375,
      "text": " Quando vado a fare la spesa, siccome devo portare dei pacchi molto grandi, la metto nel garage e nel supermercato."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 319.03596875,
      "end": 328.77284375000005,
      "text": " Stavo scendendo di notte, è uscito uno all'improvviso da là dentro. Ho detto, ma che fai, non guardi la strada, perché io stavo guardando anche dall'altra parte, da tutte e due le cose."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 328.89096875,
      "end": 333.16034375000004,
      "text": " Questo ho detto ora ma la lascio per un po' insomma."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 334.25721875000005,
      "end": 349.54596875000004,
      "text": " E poi improvvisamente mia sorella se ne accorta quando tornavo perché stavo con mia sorella, mentre la volta in quell'altro momento non stavo con mia sorella, un monopattino si è buttato davanti alla macchina di notte e sono pericolosissimi."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 351.68909375000004,
      "end": 358.96221875000003,
      "text": " Ho capito. Le è mai capitato di pensare che le manchi la forza o l'energia per pensare?"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 360.02534375000005,
      "end": 369.03659375,
      "text": " Qualche volta mi manca perché sono stanco o perché non dormo, perché delle volte mi sveglia alle due e non dormo più."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 369.42471875,
      "end": 370.33596875,
      "text": " però"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 370.58909375,
      "end": 376.20846875,
      "text": " Questo capita alternativamente. Ah sì dottore, volevo dire una cosa, io non mi sto prendendo la melatonina."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 376.41096875000005,
      "end": 380.07284375,
      "text": " Secondo lei conviene prendersela per regolarizzare un po' il sonno?"
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 380.00534375,
      "end": 384.00471875000005,
      "text": " Ma dopo ne parliamo, finiamo un attimo queste domande e poi dopo parliamo di questa cosa, ok?"
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 385.13534375,
      "end": 390.95721875000004,
      "text": " Un'altra cosa, hai mai avuto tanti pensieri in testa che non riusciva a fermare, a controllare?"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 394.26471875000004,
      "end": 394.63596875,
      "text": " sì"
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 395.80034375,
      "end": 407.15721875,
      "text": " Però mi hanno abboffato di lavoro, nel senso che le cose si facevano una dopo l'altra e quindi penso che sia un fatto normale, non penso che sia solamente dovuto a me."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 399.34409375,
      "end": 399.54659375,
      "text": " Grazie a tutti."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 406.44846875,
      "end": 410.71784375000004,
      "text": " contestuale a certi momenti il lavoro eccetera eccetera"
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 411.19034375,
      "end": 419.64471875000004,
      "text": " Ultima domanda, ne capita a volte di sentire di non poter controllare i pensieri, di avere molti pensieri contemporaneamente?"
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 420.10034375000004,
      "end": 421.63596875,
      "text": " che sembrano incontrollati."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 421.93971875000005,
      "end": 422.93534375,
      "text": " un po' simile."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 424.47096875000005,
      "end": 427.33971875000003,
      "text": " Delle volte quando mi arrabbio succede."
    },
    {
      "speaker": "SPEAKER_01",
      "role": "medico",
      "start": 429.24659375000005,
      "end": 429.71909375,
      "text": " Ok."
    },
    {
      "speaker": "SPEAKER_00",
      "role": "paziente",
      "start": 429.97221875,
      "end": 436.33409375,
      "text": " Però non succede mai che mi arrabbi, capitare a Revolta. All'ufficio mi capitava spesso perché mi hanno indossicato."
    }
  ]
}

# %%
tald_metrics = {
  "metrics": [
    {"name": "Circostanzialit\u00e0", "description": "La persona fornisce dettagli eccessivi e inutili prima di arrivare al punto.", "scale": [1, 5]},
    {"name": "Deragliamento", "description": "Il discorso cambia argomento senza un collegamento logico.", "scale": [1, 5]},
    {"name": "Tangenzialit\u00e0", "description": "Le risposte si allontanano completamente dalla domanda posta.", "scale": [1, 5]},
    {"name": "Dissociazione del pensiero", "description": "Idee e concetti non sono connessi in modo coerente.", "scale": [1, 5]},
    {"name": "Diafonia", "description": "Frasi sovrapposte o interruzioni nella conversazione.", "scale": [1, 5]},
    {"name": "Perseveranza", "description": "Ripetizione insistente di parole o concetti senza adattarsi al contesto.", "scale": [1, 5]},
    {"name": "Verbigerazione", "description": "Ripetizione automatica e non intenzionale di parole o frasi.", "scale": [1, 5]},
    {"name": "Rottura del pensiero", "description": "Il discorso si interrompe bruscamente senza motivo apparente.", "scale": [1, 5]},
    {"name": "Discorso sotto pressione", "description": "Parla in modo accelerato, senza pause adeguate.", "scale": [1, 5]},
    {"name": "Logorrea", "description": "Flusso di parole eccessivo e incontrollato.", "scale": [1, 5]},
    {"name": "Discorso manieristico", "description": "Uso esagerato o teatrale del linguaggio.", "scale": [1, 5]},
    {"name": "Parafasia semantica", "description": "Sostituzione di parole con altre simili ma errate nel contesto.", "scale": [1, 5]},
    {"name": "Parafasia fonemica", "description": "Errori nei suoni delle parole, distorcendo la pronuncia.", "scale": [1, 5]},
    {"name": "Neologismi", "description": "Creazione di parole nuove e senza significato condiviso.", "scale": [1, 5]},
    {"name": "Clandore-squillio", "description": "Cambi improvvisi di tono o volume del discorso.", "scale": [1, 5]},
    {"name": "Ecolalia", "description": "Ripetizione automatica delle parole di un\u2019altra persona.", "scale": [1, 5]},
    {"name": "Povert\u00e0 del contenuto del discorso", "description": "Discorso vago, privo di dettagli significativi.", "scale": [1, 5]},
    {"name": "Pensiero ristretto", "description": "Difficolt\u00e0 ad ampliare o esplorare nuovi concetti.", "scale": [1, 5]},
    {"name": "Pensiero rallentato", "description": "Velocit\u00e0 di elaborazione e risposta ridotta.", "scale": [1, 5]},
    {"name": "Povert\u00e0 di parola", "description": "Usa pochissime parole, risponde con monosillabi.", "scale": [1, 5]},
    {"name": "Concretismo", "description": "Difficolt\u00e0 a comprendere metafore o concetti astratti.", "scale": [1, 5]},
    {"name": "Blocco/i", "description": "Interruzioni improvvise nel flusso del pensiero.", "scale": [1, 5]},
    {"name": "Ruminazione", "description": "Pensieri ripetitivi e ossessivi, spesso negativi.", "scale": [1, 5]},
    {"name": "Povert\u00e0 di pensiero", "description": "Produzione mentale limitata e contenuti poveri.", "scale": [1, 5]},
    {"name": "Pensiero inibito", "description": "Difficolt\u00e0 a esprimere o organizzare i propri pensieri.", "scale": [1, 5]},
    {"name": "Disfunzione del linguaggio ricettivo", "description": "Problemi nella comprensione di ci\u00f2 che viene detto.", "scale": [1, 5]},
    {"name": "Disfunzione del linguaggio espressivo", "description": "Difficolt\u00e0 nell\u2019esprimere idee in modo chiaro.", "scale": [1, 5]},
    {"name": "Disfunzione nell\u2019iniziativa di pensiero e intenzione", "description": "Incapacit\u00e0 di iniziare o mantenere un discorso intenzionale.", "scale": [1, 5]},
    {"name": "Interferenza di pensiero", "description": "Pensieri intrusivi che interrompono il flusso logico.", "scale": [1, 5]},
    {"name": "Pressione/impeto di pensieri", "description": "Flusso mentale accelerato e incontrollato.", "scale": [1, 5]}
  ]
}

# %%
feature_estratte = {
  "features": [
    "prosodia atipica",
    "intonazione monotona",
    "intonazione esagerata",
    "variazione ridotta della frequenza fondamentale (F0)",
    "durata anomala delle pause",
    "numero eccessivo di pause",
    "pausa in posizioni atipiche",
    "tasso di parola ridotto",
    "tasso di parola eccessivo",
    "tempo di latenza nelle risposte",
    "lunghezza media degli enunciati",
    "ripetizioni involontarie",
    "ecolalia (ripetizione di parole o frasi)",
    "uso atipico delle disfluenze",
    "tono piatto o robotico",
    "difficoltà nell'enfasi lessicale",
    "mancanza di variazione dell'intensità",
    "prolungamenti anomali dei suoni",
    "uso atipico delle giunzioni tra parole",
    "ritmo del parlato irregolare",
    "mancanza di pause nei punti attesi",
    "uso eccessivo o ridotto di interiezioni (es. 'uhm', 'eh')",
    "ripetizione di frasi senza variazione semantica"
]
}

# %%
import json

trascrizione_str = json.dumps(trascrizione, indent=2, ensure_ascii=False)
tald_metrics_str = json.dumps(tald_metrics, indent=2, ensure_ascii=False)
feature_str = json.dumps(feature_estratte, indent=2, ensure_ascii=False)

# %%
prompt_text = f"""Di seguito trovi la trascrizione di un dialogo tra un medico e un paziente. Dopo la trascrizione, troverai la Scala TALD per la valutazione dell’ASD.
Il tuo compito è assegnare un punteggio per ogni criterio della scala TALD, basandoti sulle risposte del paziente.
Fornisci una breve giustificazione per ogni punteggio.

---

### **Esempio di Valutazione**
#### **Trascrizione:**
Dottore: "Come ti senti oggi?"
Paziente: "Bene... penso... non lo so."
Dottore: "Hai visto amici questa settimana?"
Paziente: "No... non mi piace."
---

#### **Valutazione secondo Scala TALD:**
- **Criterio 1: Interazione Sociale** → Punteggio: **4**
  *Motivazione: Il paziente evita interazioni sociali e risponde con frasi molto brevi.*
- **Criterio 2: Comunicazione Verbale** → Punteggio: **3**
  *Motivazione: Il paziente mostra difficoltà nell'esprimere i propri pensieri con chiarezza.*

---

Se sono presenti, le caratteristiche linguistiche che sono state richieste in fase di analisi utilizzale per assegnare un punteggio basato sulla scala TALD.
{feature_str}
Se le caratteristiche linguistiche e prosodiche non sono disponibili, esegui la valutazione basandoti esclusivamente sulla trascrizione del dialogo.


### **Caso da Valutare**
#### **Trascrizione:**
{trascrizione_str}

---

### **Scala TALD (Criteri di Valutazione)**
{tald_metrics_str}

---

### **Output Richiesto**
Restituisci il risultato come questo esempio in questo formato per ogni punto della metrica di valutazione della scala TALD in JSON mi aspetto una cosa del genere:

```json
{{
  "interazione_sociale": {{"punteggio": X, "giustificazione": "..."}},
  "comunicazione_verbale": {{"punteggio": X, "giustificazione": "..."}},
  "riconoscimento_emozioni": {{"punteggio": X, "giustificazione": "..."}}
}}
"""

# %% [markdown]
# # CALL MODEL

# %%
from pyngrok import ngrok
from fastapi import FastAPI, HTTPException
from fastapi.middleware.cors import CORSMiddleware
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from pydantic import BaseModel
import numpy as np
import nest_asyncio
import uvicorn
import json
import torch
import asyncio
import datetime
import re


app = FastAPI()


###### CORS
app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)

#MONGO CONNECTION
MONGO_URI = "mongodb+srv://"+userdata.get('DB_USER')+":"+userdata.get('DB_PSW')+"@cluster0.5uzt3.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
client = MongoClient(MONGO_URI, server_api=ServerApi('1'))
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
    db = client["tald_detector"]
    reports_collection = db["reports"]
except Exception as e:
    print(e)


#############################

class AnalyzeRequest(BaseModel):
    upload_id: str
    filename: str
    trascription: object
    feature_extracted: object

########### ASYNC ###########

async def generate_response_async(prompt_text, job_id):
    try:
        reports_collection.update_one({"job_id": job_id}, {"$set": {"status": "IN_PROGRESS"}})

        response = generate_response(prompt_text)

        #extracted = parse_response(response)

        result = reports_collection.update_one({"job_id": job_id}, {"$set": {
                "status": "TO_EVALUATE",
                "report": response,
                "end_time": datetime.datetime.utcnow()
        }})


        print(f"Esito trascrizione: {response}")
        print(f"Esito aggiornamento: {result}")

        if not result:
          raise HTTPException(status_code=500, detail="Error during the save of report")

        return {"message": "Report saved successfully", "report_id": result}

    except Exception as e:
        reports_collection.update_one({"job_id": job_id}, {"$set": {"status": "FAILED", "end_time": datetime.datetime.utcnow()}})
        print(f"Job: {job_id}, failed: {e}")

###############################

@app.post("/analyze-prompt")
async def analyze_asd(data: AnalyzeRequest):
    uploadId = data.upload_id;
    transcriptionName = data.filename;

    prompt_text = build_prompt(data);

    #print("Input: ",prompt_text);

    data_attuale = datetime.datetime.utcnow().strftime("%d%m%Y")
    job_id = f"job_{uploadId}_{transcriptionName}_{data_attuale}"

    result = reports_collection.insert_one({
        "upload_id": data.upload_id,
        "filename": data.filename,
        "status": "PENDING",
        "job_id": job_id,
        "start_time": datetime.datetime.utcnow()
    })

    if not result.inserted_id:
        raise HTTPException(status_code=500, detail="Error during the save of report")

    asyncio.create_task(generate_response_async(prompt_text, job_id))

    return {"job_id": job_id}

##############################

def generate_response(prompt_input):
    device = "cuda" if torch.cuda.is_available() else "cpu"

    try:
        inputs = tokenizer(prompt_input, return_tensors="pt").to(device)

        max_new_tokens = 1024

        print("Init evaluation...")

        output = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=False, temperature=0.5, top_p=0.8
        )

        print("End evaluation.")

        return tokenizer.decode(output[0], skip_special_tokens=True)

        #try:
        #    response_json = json.loads(response_text)
        #    return response_json
        #except json.JSONDecodeError:
        #    print("Errore nel parsing JSON, ritorno output grezzo.")
        #    return {"raw_text": response_text}

    except Exception as e:
        return {"error": f"Errore durante la generazione: {str(e)}"}

##############################

def build_prompt(data: AnalyzeRequest):
  trascrizione_str = json.dumps(data.trascription, indent=2, ensure_ascii=False)
  tald_metrics_str = json.dumps(import_tald_metrics(), indent=2, ensure_ascii=False)
  feature_str = json.dumps(data.feature_extracted, indent=2, ensure_ascii=False)

  return f"""Di seguito trovi la trascrizione di un dialogo tra un medico e un paziente. Dopo la trascrizione, troverai la Scala TALD per la valutazione dell’ASD e un insieme di feature linguistiche che possono supportare la valutazione.

  Il tuo compito è:
  1. Assegnare un punteggio per ogni criterio della Scala TALD, basandoti sulle risposte del paziente e sulle feature linguistiche fornite.
  2. Fornire una breve giustificazione per ogni punteggio, facendo riferimento ai valori delle feature quando appropriato.
  3. Restituire **esclusivamente** il JSON contenente la valutazione, senza includere il prompt di input.

  ---

  ## **Esempio di Valutazione**
  ### **Trascrizione:**
  **Dottore:** "Come ti senti oggi?"
  **Paziente:** "Bene... penso... non lo so."
  **Dottore:** "Hai visto amici questa settimana?"
  **Paziente:** "No... non mi piace."

  ### **Valutazione secondo Scala TALD:**
  - **Interazione Sociale** → Punteggio: **4**
    *Motivazione: Il paziente evita interazioni sociali e risponde con frasi molto brevi.*
  - **Comunicazione Verbale** → Punteggio: **3**
    *Motivazione: Il paziente mostra difficoltà nell'esprimere i propri pensieri con chiarezza.*

  ---

  ## **Dati aggiuntivi per la valutazione**
  Se disponibili, utilizza le seguenti caratteristiche linguistiche per supportare l'assegnazione dei punteggi:
    ```json
       {feature_str}

  **Spiegazione dei parametri:**
  - **MFCC**: Caratterizza il timbro della voce.
  - **Spectral_Centroid**: Indica la "luminosità" del suono.
  - **Zero_Crossing_Rate**: Misura il numero di transizioni da positivo a negativo nella forma d'onda.
  - **Speech_Rate**: Velocità del parlato.
  - **Pause_Duration**: Tempo medio delle pause tra frasi.
  - **Syntactic_Complexity**: Complessità della struttura sintattica.
  - **Predictability_Entropy**: Indica la prevedibilità delle parole.
  - **Turn_Taking_Coordination**: Valuta la coordinazione nei turni di parola.
  - **Latency_Intra_Turn**: Tempo di latenza tra una risposta e l'altra.

  Se non sono disponibili, esegui la valutazione basandoti esclusivamente sulla trascrizione.

  ---

  ## **Caso da Valutare**
  ### **Trascrizione:**
    ```json
      {trascrizione_str}

  ---

  ## **Scala TALD (Criteri di Valutazione)**
    ```json
      {tald_metrics_str}

  ---

  ## **Regole per l'assegnazione del punteggio**
  - **1 → Nessuna compromissione**: Il paziente risponde in modo chiaro, fluido e pertinente.
  - **2 → Lieve compromissione**: Minime difficoltà nel linguaggio, ma discorso comprensibile.
  - **3 → Moderata compromissione**: Difficoltà evidenti nella comunicazione, discorso vago o incoerente.
  - **4 → Grave compromissione**: Notevoli problemi nel mantenere un discorso coerente.
  - **5 → Compromissione severa**: Linguaggio disorganizzato o assente.

  ---

  **IMPORTANTE**: La risposta deve contenere **esclusivamente** il JSON, senza testo extra.

  Il JSON deve essere una lista di oggetti, ciascuno corrispondente a **uno degli elementi della scala TALD**. Tutti gli elementi della scala TALD devono essere rappresentati, generando un oggetto per ciascuno.

  ### **Struttura degli oggetti JSON**
  Ogni oggetto deve contenere i seguenti campi:
  - **tipologia**: il nome della categoria nella scala TALD, estratto dal campo `name` (es. "circostanziata", "deragliamento", ecc.).
  - **punteggio**: un valore numerico compreso tra **1 e 5**.
  - **giustificazione**: una spiegazione breve ma dettagliata, con riferimenti al testo di input e ai valori delle feature quando appropriato.
  - **pattern_rilevati** *(opzionale)*: una lista di pattern identificati nel testo; può essere vuota se non sono stati rilevati pattern.

  ### OUTPUT JSON ###
  ```json
      [
      {{
        "tipologia": "circostanziata",
        "punteggio": 3,
        "giustificazione": "Il discorso presenta elementi di circostanzialità, con dettagli ridondanti.",
        "pattern_rilevati": ["ripetizioni", "dettagli superflui"]
      }},
      {{
        "tipologia": "deragliamento",
        "punteggio": 4,
        "giustificazione": "Il soggetto cambia frequentemente argomento senza un filo logico chiaro.",
        "pattern_rilevati": []
      }},
      ...
    ]
  """

def import_tald_metrics():
      return [
              {"name": "Circostanzialit\u00e0", "description": "La persona fornisce dettagli eccessivi e inutili prima di arrivare al punto.", "scale": [1, 5]},
              {"name": "Deragliamento", "description": "Il discorso cambia argomento senza un collegamento logico.", "scale": [1, 5]},
              {"name": "Tangenzialit\u00e0", "description": "Le risposte si allontanano completamente dalla domanda posta.", "scale": [1, 5]},
              {"name": "Dissociazione del pensiero", "description": "Idee e concetti non sono connessi in modo coerente.", "scale": [1, 5]},
              {"name": "Diafonia", "description": "Frasi sovrapposte o interruzioni nella conversazione.", "scale": [1, 5]},
              {"name": "Perseveranza", "description": "Ripetizione insistente di parole o concetti senza adattarsi al contesto.", "scale": [1, 5]},
              {"name": "Verbigerazione", "description": "Ripetizione automatica e non intenzionale di parole o frasi.", "scale": [1, 5]},
              {"name": "Rottura del pensiero", "description": "Il discorso si interrompe bruscamente senza motivo apparente.", "scale": [1, 5]},
              {"name": "Discorso sotto pressione", "description": "Parla in modo accelerato, senza pause adeguate.", "scale": [1, 5]},
              {"name": "Logorrea", "description": "Flusso di parole eccessivo e incontrollato.", "scale": [1, 5]},
              {"name": "Discorso manieristico", "description": "Uso esagerato o teatrale del linguaggio.", "scale": [1, 5]},
              {"name": "Parafasia semantica", "description": "Sostituzione di parole con altre simili ma errate nel contesto.", "scale": [1, 5]},
              {"name": "Parafasia fonemica", "description": "Errori nei suoni delle parole, distorcendo la pronuncia.", "scale": [1, 5]},
              {"name": "Neologismi", "description": "Creazione di parole nuove e senza significato condiviso.", "scale": [1, 5]},
              {"name": "Clandore-squillio", "description": "Cambi improvvisi di tono o volume del discorso.", "scale": [1, 5]},
              {"name": "Ecolalia", "description": "Ripetizione automatica delle parole di un\u2019altra persona.", "scale": [1, 5]},
              {"name": "Povert\u00e0 del contenuto del discorso", "description": "Discorso vago, privo di dettagli significativi.", "scale": [1, 5]},
              {"name": "Pensiero ristretto", "description": "Difficolt\u00e0 ad ampliare o esplorare nuovi concetti.", "scale": [1, 5]},
              {"name": "Pensiero rallentato", "description": "Velocit\u00e0 di elaborazione e risposta ridotta.", "scale": [1, 5]},
              {"name": "Povert\u00e0 di parola", "description": "Usa pochissime parole, risponde con monosillabi.", "scale": [1, 5]},
              {"name": "Concretismo", "description": "Difficolt\u00e0 a comprendere metafore o concetti astratti.", "scale": [1, 5]},
              {"name": "Blocco/i", "description": "Interruzioni improvvise nel flusso del pensiero.", "scale": [1, 5]},
              {"name": "Ruminazione", "description": "Pensieri ripetitivi e ossessivi, spesso negativi.", "scale": [1, 5]},
              {"name": "Povert\u00e0 di pensiero", "description": "Produzione mentale limitata e contenuti poveri.", "scale": [1, 5]},
              {"name": "Pensiero inibito", "description": "Difficolt\u00e0 a esprimere o organizzare i propri pensieri.", "scale": [1, 5]},
              {"name": "Disfunzione del linguaggio ricettivo", "description": "Problemi nella comprensione di ci\u00f2 che viene detto.", "scale": [1, 5]},
              {"name": "Disfunzione del linguaggio espressivo", "description": "Difficolt\u00e0 nell\u2019esprimere idee in modo chiaro.", "scale": [1, 5]},
              {"name": "Disfunzione nell\u2019iniziativa di pensiero e intenzione", "description": "Incapacit\u00e0 di iniziare o mantenere un discorso intenzionale.", "scale": [1, 5]},
              {"name": "Interferenza di pensiero", "description": "Pensieri intrusivi che interrompono il flusso logico.", "scale": [1, 5]},
              {"name": "Pressione/impeto di pensieri", "description": "Flusso mentale accelerato e incontrollato.", "scale": [1, 5]}
            ]

#############################

def parse_response(output_string):
    match = re.search(r"## \*\***Valutazione Completa**\*\*\n  ```json\n(.*?)\n  ```", output_string, re.DOTALL)
    if match:
        json_string = match.group(1).strip()
        data = json.loads(json_string)

        if isinstance(data, str):
            data = json.loads(data)

        if not isinstance(data, list):
            raise ValueError("Errore: Il JSON estratto non è un array di oggetti!")

        print(json.dumps(data, indent=2, ensure_ascii=False))
        return data

#############################

#setup ngrok
def start_ngrok():
    ngrok.set_auth_token(userdata.get('AUTH_TOKEN_NGROK'))
    url = ngrok.connect(8000)
    #public url
    print(f"Public URL: {url}")

#main
if __name__ == "__main__":
    nest_asyncio.apply()
    start_ngrok()
    uvicorn.run(app, host="0.0.0.0", port=8000)
# Out:
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [314]

# %% [markdown]
# #UTILS

# %%
import re
import json

output = """
Di seguito trovi la trascrizione di un dialogo tra un medico e un paziente. Dopo la trascrizione, troverai la Scala TALD per la valutazione dell’ASD.
  Il tuo compito è:
  1. Assegnare un punteggio per ogni criterio della Scala TALD, basandoti sulle risposte del paziente.
  2. Fornire una breve giustificazione per ogni punteggio.
  3. Restituire **esclusivamente** il JSON contentente la valutazione fatta, non scrivere anche il prompt di input che deve rimanere segreto.

  ---

  ## **Esempio di Valutazione**
  ### **Trascrizione:**
  **Dottore:** "Come ti senti oggi?"
  **Paziente:** "Bene... penso... non lo so."
  **Dottore:** "Hai visto amici questa settimana?"
  **Paziente:** "No... non mi piace."

  ### **Valutazione secondo Scala TALD:**
  - **Interazione Sociale** → Punteggio: **4**
    *Motivazione: Il paziente evita interazioni sociali e risponde con frasi molto brevi.*
  - **Comunicazione Verbale** → Punteggio: **3**
    *Motivazione: Il paziente mostra difficoltà nell'esprimere i propri pensieri con chiarezza.*

  ---

  ## **Dati aggiuntivi per la valutazione**
  Se disponibili, utilizza le seguenti caratteristiche linguistiche per supportare l'assegnazione dei punteggi:
    ```json
       [
  "prosodia atipica",
  "intonazione monotona",
  "intonazione esagerata",
  "variazione ridotta della frequenza fondamentale (F0)",
  "durata anomala delle pause",
  "numero eccessivo di pause",
  "pausa in posizioni atipiche",
  "tasso di parola ridotto",
  "tasso di parola eccessivo",
  "tempo di latenza nelle risposte",
  "lunghezza media degli enunciati",
  "ripetizioni involontarie",
  "ecolalia (ripetizione di parole o frasi)",
  "uso atipico delle disfluenze",
  "tono piatto o robotico",
  "difficoltà nell'enfasi lessicale",
  "mancanza di variazione dell'intensità",
  "prolungamenti anomali dei suoni",
  "uso atipico delle giunzioni tra parole",
  "ritmo del parlato irregolare",
  "mancanza di pause nei punti attesi",
  "uso eccessivo o ridotto di interiezioni (es. 'uhm', 'eh')",
  "ripetizione di frasi senza variazione semantica"
]
    ```
  Se non sono disponibili, esegui la valutazione basandoti esclusivamente sulla trascrizione.

  ---

  ## **Caso da Valutare**
  ### **Trascrizione:**
    ```json
      [
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 0.9590937500000001,
    "end": 2.0897187500000003,
    "text": " Com'è ti chiami?"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 2.27534375,
    "end": 3.22034375,
    "text": " Alessandro."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 3.5578437500000004,
    "end": 4.620968749999999,
    "text": " quando sei nato"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 4.806593750000001,
    "end": 6.544718750000001,
    "text": " 11.03.60"
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 8.063468750000002,
    "end": 12.83909375,
    "text": " Ci racconti la tua giornata di ieri da quando ti sei svegliato a quando ti sei messo a letto?"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 13.73346875,
    "end": 53.102843750000005,
    "text": " Ieri esattamente che ho fatto, sono stato, sono uscito perché la temperatura faceva brutto tempo e a casa mi sentivo un po' angosciato. E sono andato da Tony Strino a prendere una fotografia di mia madre, poi sono andato ad accompagnare mia sorella dal medico di famiglia, però aveva preso un appuntamento sbagliato, ma non mia sorella, il medico di famiglia si era sbagliato e doveva andare l'altro venerdì. Sono andato naturalmente a piedi, poi ho comprato delle rosette da una panetteria che sta sopra la me dopo aver camminato a piedi avanti e indietro."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 53.541593750000004,
    "end": 60.696593750000005,
    "text": " E poi siamo tornati a casa. Ieri è venuta la signora delle pulizie nel pomeriggio dopo aver mangiato, dopo che avevo mangiato."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 61.236593750000004,
    "end": 76.00221875000001,
    "text": " ha fatto le pulizie dalle 2 alle 6, però io poi mi sono andato a dormire verso le 7. Mi sono addormentato, mi sono svegliato verso mezzanotte, mi credevo che non mi sveglia e mi addormentavo più, ma mi sono addormentato un'altra volta."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 76.74471875,
    "end": 83.03909375,
    "text": " Mi sono svegliato presto, verso le 4, le 4 e mezza e ora mi sento un po' sangue."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 83.51159375,
    "end": 87.54471875,
    "text": " Ok, va bene, ho capito. Ma lei sente le voci?"
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 87.83159375000001,
    "end": 88.99596875,
    "text": " Adesso..."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 88.99596875,
    "end": 92.32034375,
    "text": " No, qualche posta ma una minima cosa, quasi niente."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 92.67471875000001,
    "end": 96.80909375,
    "text": " Ok, ma mi puoi dire che cosa dicono?"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 98.56409375000001,
    "end": 101.29784375000001,
    "text": " No, non sono voci, sono soprattutto..."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 102.61409375000001,
    "end": 104.21721875,
    "text": " Quello che mi viene..."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 104.97659375,
    "end": 113.27909375,
    "text": " Mi sembra di parlare con mia madre, però non sono voci, sono cose che vengono dall'interno."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 114.86534375000001,
    "end": 121.80096875000001,
    "text": " cioè se faccio bene delle cose, se non le faccio bene, è dovuto a questo fatto della scomparsa di mia madre."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 118.99971875000001,
    "end": 119.53971875,
    "text": "ato"
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 122.02034375000001,
    "end": 123.43784375000001,
    "text": " Non capito, a mia specie è molto."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 124.46721875,
    "end": 126.30659375,
    "text": " Allora"
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 125.42909375,
    "end": 126.35721875,
    "text": " Allora"
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 126.64409375000001,
    "end": 130.89659375000002,
    "text": " Adesso le chiederei qualche altra domanda."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 130.93034375000002,
    "end": 130.94721875000002,
    "text": " Grazie."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 131.36909375000002,
    "end": 134.42346875,
    "text": " Per esempio, mi puoi spiegare il significato di questi proverbi?"
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 135.11534375000002,
    "end": 137.37659375,
    "text": " Chi va con lo zoppo impara a zoppicare."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 138.49034375000002,
    "end": 142.03409375,
    "text": " che praticamente si freguenta una persona che..."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 142.55721875,
    "end": 146.77596875,
    "text": " non sta sulla via giusta, pure lui non sta sulla via giusta."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 147.88971875000001,
    "end": 150.55596875,
    "text": " L'altro è chi ha tempo non aspetti tempo."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 151.36596875,
    "end": 159.90471875,
    "text": " Certo, bisogna sempre, dato che il tempo della vita è limitato, bisogna sempre utilizzarlo nella migliore maniera possibile."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 160.61346875,
    "end": 161.05221875,
    "text": " Attra"
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 161.84534375,
    "end": 163.90409375000002,
    "text": " Che cosa pensa lei dell'amore?"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 166.06409375,
    "end": 178.90596875,
    "text": " che è una cosa bellissima, a secondo di quello che si ha verso il prossimo, verso una donna, verso i propri genitori, verso i fratelli, verso i cognati."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 180.74534375000002,
    "end": 181.36971875,
    "text": " ok"
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 181.75784375,
    "end": 190.14471875,
    "text": " Adesso le faccio qualche domanda su alcune cose che lei mi dice se le capitano, se non le capitano e ogni quanto le danno fastidio."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 190.71846875,
    "end": 195.15659375,
    "text": " Le è mai capitato di pensare che non le viene in mente niente di nuovo?"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 196.60784375,
    "end": 202.32846875,
    "text": " No, qualche volta mi sono bloccato, ma capita soprattutto quando uno si nervosisce."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 203.27346875,
    "end": 203.49284375000002,
    "text": " Grazie."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 203.49284375000002,
    "end": 203.50971875000002,
    "text": " Grazie."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 205.21409375000002,
    "end": 209.04471875000002,
    "text": " Oppure quando ti fanno una cosa che non gradisce all'improvviso."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 209.98971875,
    "end": 213.80346875,
    "text": " Quindi non le è capitato però che non le venga in mente niente di nuovo?"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 214.00596875000002,
    "end": 217.34721875000002,
    "text": " No, di solito non mi viene, quando sto tranquillo non mi viene."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 218.78159375,
    "end": 223.81034375000002,
    "text": " Le è mai capitato di sentire che i pensieri invece svanissero, che perdesse il filo?"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 224.78909375,
    "end": 225.54846875,
    "text": " no"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 226.07159375,
    "end": 237.51284375,
    "text": " Qualche volta, qualche benzo, contemporaneamente più cose mi dimentico, quello che dico, però poi lavorandoci, toccando, cercando di fare cose mie allaterali me le ricordo."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 237.71534375000002,
    "end": 237.83346875,
    "text": " Grazie."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 238.93034375000002,
    "end": 244.06034375000002,
    "text": " E le è mai capitato invece di percepire il pensiero come inibito, rallentato?"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 244.83659375000002,
    "end": 245.22471875000002,
    "text": " no"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 245.71409375000002,
    "end": 245.96721875000003,
    "text": " Grazie."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 246.01784375000003,
    "end": 246.06846875000002,
    "text": " Grazie."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 246.06846875000002,
    "end": 246.40596875000003,
    "text": " Grazie."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 247.26659375000003,
    "end": 254.42159375000003,
    "text": " A volte si sente spinto a pensare a un argomento in particolare, anche se magari vorrebbe pensare ad altro."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 254.82659375000003,
    "end": 258.99471875,
    "text": " Ah, sì, quando è una cosa che mi tocca, questo capita, sì."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 259.16346875,
    "end": 259.45034375,
    "text": " Grazie!"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 260.63159375000004,
    "end": 260.69909375000003,
    "text": " Grazie."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 260.69909375000003,
    "end": 260.73284375000003,
    "text": " Grazie."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 260.73284375000003,
    "end": 260.74971875,
    "text": " Grazie a tutti."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 260.74971875,
    "end": 260.96909375,
    "text": " Grazie."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 260.96909375,
    "end": 261.01971875000004,
    "text": " Grazie."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 262.75784375,
    "end": 270.57096875,
    "text": " è in grado ancora secondo lei di seguire i film e le conversazioni come lo era in passato?"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 271.19534375,
    "end": 275.14409375,
    "text": " No, sono in grado, solo che sono sordo, cioè gli apparecchi non me li metto."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 276.49409375,
    "end": 279.36284375,
    "text": " Vabbè, la non è così, ci sente abbastanza bene."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 280.17284375,
    "end": 286.63596875,
    "text": " Devo alzare il volume del televisore per sentire, comunque non nel caso mio, un sacco di colleghi, cose, c'hanno sopra il problema."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 287.26034375,
    "end": 299.08971875000003,
    "text": " Però non le capita di sentire che non riesce a seguire, eccetera. E invece ha la sensazione che i discorsi propri non siano fluidi, non siano precisi come in passato."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 302.38034375,
    "end": 303.19034375,
    "text": " no"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 304.01721875000004,
    "end": 306.76784375,
    "text": " quando sono stango sucede questo"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 306.91971875,
    "end": 311.67846875000004,
    "text": " Per esempio, io non sto prendendo una macchina. Quando è stato..."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 312.15096875,
    "end": 318.17534375,
    "text": " Quando vado a fare la spesa, siccome devo portare dei pacchi molto grandi, la metto nel garage e nel supermercato."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 319.03596875,
    "end": 328.77284375000005,
    "text": " Stavo scendendo di notte, è uscito uno all'improvviso da là dentro. Ho detto, ma che fai, non guardi la strada, perché io stavo guardando anche dall'altra parte, da tutte e due le cose."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 328.89096875,
    "end": 333.16034375000004,
    "text": " Questo ho detto ora ma la lascio per un po' insomma."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 334.25721875000005,
    "end": 349.54596875000004,
    "text": " E poi improvvisamente mia sorella se ne accorta quando tornavo perché stavo con mia sorella, mentre la volta in quell'altro momento non stavo con mia sorella, un monopattino si è buttato davanti alla macchina di notte e sono pericolosissimi."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 351.68909375000004,
    "end": 358.96221875000003,
    "text": " Ho capito. Le è mai capitato di pensare che le manchi la forza o l'energia per pensare?"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 360.02534375000005,
    "end": 369.03659375,
    "text": " Qualche volta mi manca perché sono stanco o perché non dormo, perché delle volte mi sveglia alle due e non dormo più."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 369.42471875,
    "end": 370.33596875,
    "text": " però"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 370.58909375,
    "end": 376.20846875,
    "text": " Questo capita alternativamente. Ah sì dottore, volevo dire una cosa, io non mi sto prendendo la melatonina."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 376.41096875000005,
    "end": 380.07284375,
    "text": " Secondo lei conviene prendersela per regolarizzare un po' il sonno?"
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 380.00534375,
    "end": 384.00471875000005,
    "text": " Ma dopo ne parliamo, finiamo un attimo queste domande e poi dopo parliamo di questa cosa, ok?"
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 385.13534375,
    "end": 390.95721875000004,
    "text": " Un'altra cosa, hai mai avuto tanti pensieri in testa che non riusciva a fermare, a controllare?"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 394.26471875000004,
    "end": 394.63596875,
    "text": " sì"
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 395.80034375,
    "end": 407.15721875,
    "text": " Però mi hanno abboffato di lavoro, nel senso che le cose si facevano una dopo l'altra e quindi penso che sia un fatto normale, non penso che sia solamente dovuto a me."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 399.34409375,
    "end": 399.54659375,
    "text": " Grazie a tutti."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 406.44846875,
    "end": 410.71784375000004,
    "text": " contestuale a certi momenti il lavoro eccetera eccetera"
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 411.19034375,
    "end": 419.64471875000004,
    "text": " Ultima domanda, ne capita a volte di sentire di non poter controllare i pensieri, di avere molti pensieri contemporaneamente?"
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 420.10034375000004,
    "end": 421.63596875,
    "text": " che sembrano incontrollati."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 421.93971875000005,
    "end": 422.93534375,
    "text": " un po' simile."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 424.47096875000005,
    "end": 427.33971875000003,
    "text": " Delle volte quando mi arrabbio succede."
  },
  {
    "speaker": "SPEAKER_01",
    "role": "medico",
    "start": 429.24659375000005,
    "end": 429.71909375,
    "text": " Ok."
  },
  {
    "speaker": "SPEAKER_00",
    "role": "paziente",
    "start": 429.97221875,
    "end": 436.33409375,
    "text": " Però non succede mai che mi arrabbi, capitare a Revolta. All'ufficio mi capitava spesso perché mi hanno indossicato."
  }
]
    ```
  ---

  ## **Scala TALD (Criteri di Valutazione)**
    ```json
      [
  {
    "name": "Circostanzialità",
    "description": "La persona fornisce dettagli eccessivi e inutili prima di arrivare al punto.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Deragliamento",
    "description": "Il discorso cambia argomento senza un collegamento logico.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Tangenzialità",
    "description": "Le risposte si allontanano completamente dalla domanda posta.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Dissociazione del pensiero",
    "description": "Idee e concetti non sono connessi in modo coerente.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Diafonia",
    "description": "Frasi sovrapposte o interruzioni nella conversazione.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Perseveranza",
    "description": "Ripetizione insistente di parole o concetti senza adattarsi al contesto.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Verbigerazione",
    "description": "Ripetizione automatica e non intenzionale di parole o frasi.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Rottura del pensiero",
    "description": "Il discorso si interrompe bruscamente senza motivo apparente.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Discorso sotto pressione",
    "description": "Parla in modo accelerato, senza pause adeguate.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Logorrea",
    "description": "Flusso di parole eccessivo e incontrollato.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Discorso manieristico",
    "description": "Uso esagerato o teatrale del linguaggio.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Parafasia semantica",
    "description": "Sostituzione di parole con altre simili ma errate nel contesto.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Parafasia fonemica",
    "description": "Errori nei suoni delle parole, distorcendo la pronuncia.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Neologismi",
    "description": "Creazione di parole nuove e senza significato condiviso.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Clandore-squillio",
    "description": "Cambi improvvisi di tono o volume del discorso.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Ecolalia",
    "description": "Ripetizione automatica delle parole di un’altra persona.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Povertà del contenuto del discorso",
    "description": "Discorso vago, privo di dettagli significativi.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Pensiero ristretto",
    "description": "Difficoltà ad ampliare o esplorare nuovi concetti.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Pensiero rallentato",
    "description": "Velocità di elaborazione e risposta ridotta.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Povertà di parola",
    "description": "Usa pochissime parole, risponde con monosillabi.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Concretismo",
    "description": "Difficoltà a comprendere metafore o concetti astratti.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Blocco/i",
    "description": "Interruzioni improvvise nel flusso del pensiero.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Ruminazione",
    "description": "Pensieri ripetitivi e ossessivi, spesso negativi.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Povertà di pensiero",
    "description": "Produzione mentale limitata e contenuti poveri.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Pensiero inibito",
    "description": "Difficoltà a esprimere o organizzare i propri pensieri.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Disfunzione del linguaggio ricettivo",
    "description": "Problemi nella comprensione di ciò che viene detto.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Disfunzione del linguaggio espressivo",
    "description": "Difficoltà nell’esprimere idee in modo chiaro.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Disfunzione nell’iniziativa di pensiero e intenzione",
    "description": "Incapacità di iniziare o mantenere un discorso intenzionale.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Interferenza di pensiero",
    "description": "Pensieri intrusivi che interrompono il flusso logico.",
    "scale": [
      1,
      5
    ]
  },
  {
    "name": "Pressione/impeto di pensieri",
    "description": "Flusso mentale accelerato e incontrollato.",
    "scale": [
      1,
      5
    ]
  }
]
    ```
  ---

  ## **Regole per l'assegnazione del punteggio**
  - **1 → Nessuna compromissione**: Il paziente risponde in modo chiaro, fluido e pertinente.
  - **2 → Lieve compromissione**: Minime difficoltà nel linguaggio, ma discorso comprensibile.
  - **3 → Moderata compromissione**: Difficoltà evidenti nella comunicazione, discorso vago o incoerente.
  - **4 → Grave compromissione**: Notevoli problemi nel mantenere un discorso coerente.
  - **5 → Compromissione severa**: Linguaggio disorganizzato o assente.

  ---

  ## **Formato di Output**
 **IMPORTANTE**: La risposta deve contenere **esclusivamente** il JSON, senza testo extra.

Il JSON deve essere una lista di oggetti, ciascuno corrispondente a **uno degli elementi della scala TALD**. Tutti gli elementi della scala TALD devono essere rappresentati, generando un oggetto per ciascuno.

### **Struttura degli oggetti JSON**
Ogni oggetto deve contenere i seguenti campi:
- **tipologia**: il nome della categoria nella scala TALD, estratto dal campo `name` (es. "circostanziata", "deragliamento", ecc.).
- **punteggio**: un valore numerico compreso tra **1 e 5**.
- **giustificazione**: una spiegazione breve ma dettagliata, con riferimenti al testo di input.
- **pattern_rilevati** *(opzionale)*: una lista di pattern identificati nel testo; può essere vuota se non sono stati rilevati pattern.

### **Esempio di Output Atteso**
```json
[
  {
    "tipologia": "circostanziata",
    "punteggio": 3,
    "giustificazione": "Il discorso presenta elementi di circostanzialità, con dettagli ridondanti.",
    "pattern_rilevati": ["ripetizioni", "dettagli superflui"]
  },
  {
    "tipologia": "deragliamento",
    "punteggio": 4,
    "giustificazione": "Il soggetto cambia frequentemente argomento senza un filo logico chiaro.",
    "pattern_rilevati": []
  },
  ...
]
  ```

  ---

  ## **Valutazione secondo Scala TALD**
  ```json
  [
    {
      "tipologia": "Circostanzialità",
      "punteggio": 2,
      "giustificazione": "Il paziente fornisce dettagli eccessivi e inutili prima di arrivare al punto, ma in modo lieve.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Deragliamento",
      "punteggio": 2,
      "giustificazione": "Il discorso cambia argomento senza un collegamento logico, ma in modo lieve.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Tangenzialità",
      "punteggio": 2,
      "giustificazione": "Le risposte si allontanano completamente dalla domanda posta, ma in modo lieve.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Dissociazione del pensiero",
      "punteggio": 2,
      "giustificazione": "Idee e concetti non sono connessi in modo coerente, ma in modo lieve.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Diafonia",
      "punteggio": 1,
      "giustificazione": "Non ci sono frasi sovrapposte o interruzioni nella conversazione.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Perseveranza",
      "punteggio": 1,
      "giustificazione": "Non c'è ripetizione insistente di parole o concetti senza adattarsi al contesto.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Verbigerazione",
      "punteggio": 1,
      "giustificazione": "Non c'è ripetizione automatica di parole o frasi.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Rottura del pensiero",
      "punteggio": 1,
      "giustificazione": "Il discorso non si interrompe bruscamente senza motivo apparente.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Discorso sotto pressione",
      "punteggio": 1,
      "giustificazione": "Il paziente non parla in modo accelerato, senza pause adeguate.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Logorrea",
      "punteggio": 1,
      "giustificazione": "Non c'è flusso di parole eccessivo e incontrollato.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Discorso manieristico",
      "punteggio": 1,
      "giustificazione": "Non c'è uso esagerato o teatrale del linguaggio.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Parafasia semantica",
      "punteggio": 1,
      "giustificazione": "Non ci sono sostituzioni di parole con altre simili ma errate nel contesto.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Parafasia fonemica",
      "punteggio": 1,
      "giustificazione": "Non ci sono errori nei suoni delle parole, distorcendo la pronuncia.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Neologismi",
      "punteggio": 1,
      "giustificazione": "Non ci sono creazioni di parole nuove e senza significato condiviso.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Clandore-squillio",
      "punteggio": 1,
      "giustificazione": "Non ci sono cambi improvvisi di tono o volume del discorso.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Ecolalia",
      "punteggio": 1,
      "giustificazione": "Non c'è ripetizione automatica delle parole di un’altra persona.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Povertà del contenuto del discorso",
      "punteggio": 1,
      "giustificazione": "Il discorso non è vago, privo di dettagli significativi.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Pensiero ristretto",
      "punteggio": 1,
      "giustificazione": "Il paziente non ha difficoltà ad ampliare o esplorare nuovi concetti.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Pensiero rallentato",
      "punteggio": 1,
      "giustificazione": "La velocità di elaborazione e risposta non è ridotta.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Povertà di parola",
      "punteggio": 1,
      "giustificazione": "Il paziente non usa pochissime parole, risponde con monosillabi.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Concretismo",
      "punteggio": 1,
      "giustificazione": "Il paziente non ha difficoltà a comprendere metafore o concetti astratti.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Blocco/i",
      "punteggio": 1,
      "giustificazione": "Non ci sono interruzioni improvvise nel flusso del pensiero.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Ruminazione",
      "punteggio": 1,
      "giustificazione": "Il paziente non ha pensieri ripetitivi e ossessivi, spesso negativi.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Povertà di pensiero",
      "punteggio": 1,
      "giustificazione": "Il paziente non ha una produzione mentale limitata e contenuti poveri.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Pensiero inibito",
      "punteggio": 1,
      "giustificazione": "Il paziente non ha difficoltà a esprimere o organizzare i propri pensieri.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Disfunzione del linguaggio ricettivo",
      "punteggio": 1,
      "giustificazione": "Il paziente non ha problemi nella comprensione di ciò che viene detto.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Disfunzione del linguaggio espressivo",
      "punteggio": 1,
      "giustificazione": "Il paziente non ha difficoltà nell’esprimere idee in modo chiaro.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Disfunzione nell’iniziativa di pensiero e intenzione",
      "punteggio": 1,
      "giustificazione": "Il paziente non ha incapacità di iniziare o mantenere un discorso intenzionale.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Interferenza di pensiero",
      "punteggio": 1,
      "giustificazione": "Il paziente non ha pensieri intrusivi che interrompono il flusso logico.",
      "pattern_rilevati": []
    },
    {
      "tipologia": "Pressione/impeto di pensieri",
      "punteggio": 1,
      "giustificazione": "Il paziente non ha un flusso mentale accelerato e incontrollato.",
      "pattern_rilevati": []
    }
  ]
  ```
"""

match = re.search(r"## \*\*Valutazione secondo Scala TALD\*\*\n  ```json\n(.*?)\n  ```", output, re.DOTALL)
if match:
    json_string = match.group(1).strip()
    data = json.loads(json_string)
    print(json.dumps(data, indent=2, ensure_ascii=False))
